# %%
#For this we need to build for classes
#1 . Card class - Hold the information about the card
#2 . Deck class - Hold the information baout the complete set of 52 cards
#3 . Player class - Hold the information about the cards the player are having
#4 . Table class - Holds the information about the cards on table.\

'''
1. This game involves two players and initialy each player is given 26 cards each.
2. They have to put there top card on the table turn wise
3. If the card they are going to put on table matchs with the already top card on the table
MATCH condition - Two cards match if they have same suit OR if they have same rank
4. Player wins that chance and he take all the cards on the table and add all those cards to the end of the deck of cards he
already have.
5. This way game runs until one of the player run out of cards
6. The player that run out of cards losses and other player wins the game!!!!!
'''

import random

suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 'Nine':9, 'Ten':10, 'Jack':10,
         'Queen':10, 'King':10, 'Ace':11}

playing = True

class Card:

    def __init__(self,suit,rank):
        self.suit = suit           # identity of a card
        self.rank = rank
        
    def __str__(self):
        return self.rank + ' of ' + self.suit     #returns a string defining the card

class Deck:
    
    def __init__(self):
        self.deck = []  # start with an empty list
        for suit in suits:
            for rank in ranks:
                self.deck.append(Card(suit,rank))  # build Card objects and add them to the list
    
    def __str__(self):
        deck_comp = ''  # start with an empty string
        for card in self.deck:
            deck_comp += '\n '+card.__str__() # add each Card object's print string
        return 'The deck has:' + deck_comp

    def shuffle(self):           # Shuffles the 52 cards
        random.shuffle(self.deck)          
    def __len__(self):
        return len(self.deck)

class Player:
    def __init__(self,name):
        self.cards = []
        self.name = name
    def add(self , new_cards):          # Add the cards from the table after the persor wins
        self.cards.extend(new_cards)  
        
    def move(self):                     #Puts one card on the table
        return self.cards.pop(0)
    
    def __str__(self):
        ans =''
        for cards in self.cards:
            ans += '\n' + cards.__str__()
        return  self.name +" has the following cards:" +ans
    def __len__(self):
        return len(self.cards)
class Table:
    def __init__(self):
        self.cards = []
    
    def add(self , new_cards):                     #Adds the new card to the table as the player moves 
        self.cards.append(new_cards)
        
    def remove(self):                                #All the cards are removed and given to a particular person
        self.cards = []
    
    def __str__(self):
        ans = ''
        for cards in self.cards:
            ans += '\n' + cards.__str__()
        return "Table has the following cards:" + ans
    def __len__(self):
        return len(self.cards)
def player_name():   
    user_1 = input("Hi! Please enter name of first player")  #stores the name of first user
    print("Hi" , user_1)
    user_2 = input("Hi! Please enter name of second player") #stores the name of second user
    print("Hi" ,user_2)
    return(user_1 ,user_2 )

deck = Deck()
deck.shuffle()
len(deck)

name_1 , name_2 = player_name()
user_1 = Player(name_1)
user_2 = Player(name_2)

user_1.add(deck.deck[0:26])
user_2.add(deck.deck[26:52])

print(user_1)
print(user_2)

table = Table()

player =1
while(True):
    print("No of cards with",user_1.name,"are",len(user_1))
    print("No of cards with",user_2.name,"are",len(user_2))
    print("No of cards on table are",len(table))
    print('\n')
    if player == 1:
        card = user_1.move()
        print(user_1.name,"Please press enter to move a chance. You have a",card.__str__() ,'\n')
        a = input("Press any key")
        print("Top Cards on table are",'\n')
        table.add(card)
        print(table.cards[-1])
        if len(table) > 1:
            print(table.cards[-2])
        if len(table) > 1:
            if table.cards[-1].suit == table.cards[-2].suit or table.cards[-1].rank == table.cards[-2].rank:
                print("Woohho Top two cards match" , user_1.name, "Wins this move",'\n')
                user_1.add(table.cards[::-1])
                table.remove()
        player = 2
    else :
        card = user_2.move()
        print(user_2.name,"Please press enter to move a chance. You have a",card.__str__(),'\n')
        a = input("Press any key")
        print("Top Cards on table are",'\n')
        table.add(card)
        print(table.cards[-1])
        if len(table) > 1:
            print(table.cards[-2])
        if len(table) > 1:
            if table.cards[-1].suit == table.cards[-2].suit or table.cards[-1].rank == table.cards[-2].rank:
                print("Woohho Top two cards match" , user_2.name, "Wins this move",'\n')
                user_2.add(table.cards[::-1])
                table.remove()
        player = 1
    print('\n')
    if len(user_1) == 0:
        print("Congrats",user_2.name,"Won")
        break
    if len(user_2) == 0:
        print("Congrats",user_1.name,"Won")
        break
# Out:
# Hi! Please enter name of first playermb
# Hi mb
# Hi! Please enter name of second playeref,w.
# Hi ef,w.
# mb has the following cards:
# Three of Clubs
# Ten of Clubs
# King of Spades
# Jack of Spades
# Two of Hearts
# Queen of Diamonds
# Six of Diamonds
# Six of Spades
# Six of Clubs
# Two of Spades
# Nine of Clubs
# Five of Hearts
# Five of Diamonds
# King of Diamonds
# Five of Clubs
# Ten of Hearts
# Three of Spades
# Ace of Spades
# Nine of Hearts
# Seven of Diamonds
# Nine of Diamonds
# Two of Clubs
# Three of Diamonds
# Queen of Clubs
# Four of Clubs
# Ace of Clubs
# ef,w. has the following cards:
# Four of Diamonds
# Jack of Diamonds
# Queen of Spades
# Seven of Hearts
# Eight of Diamonds
# Ten of Diamonds
# Four of Spades
# King of Hearts
# Two of Diamonds
# Ten of Spades
# Jack of Hearts
# Seven of Clubs
# King of Clubs
# Jack of Clubs
# Ace of Diamonds
# Five of Spades
# Queen of Hearts
# Four of Hearts
# Eight of Spades
# Six of Hearts
# Eight of Hearts
# Ace of Hearts
# Three of Hearts
# Seven of Spades
# Eight of Clubs
# Nine of Spades
# No of cards with mb are 26
# No of cards with ef,w. are 26
# No of cards on table are 0
#
#
# mb Please press enter to move a chance. You have a Three of Clubs
#
# Press any keyf
# Top Cards on table are
#
# Three of Clubs
#
#
# No of cards with mb are 25
# No of cards with ef,w. are 26
# No of cards on table are 1
#
#
# ef,w. Please press enter to move a chance. You have a Four of Diamonds
#
# Press any keyg
# Top Cards on table are
#
# Four of Diamonds
# Three of Clubs
#
#
# No of cards with mb are 25
# No of cards with ef,w. are 25
# No of cards on table are 2
#
#
# mb Please press enter to move a chance. You have a Ten of Clubs
#
# Press any keyg
# Top Cards on table are
#
# Ten of Clubs
# Four of Diamonds
#
#
# No of cards with mb are 24
# No of cards with ef,w. are 25
# No of cards on table are 3
#
#
# ef,w. Please press enter to move a chance. You have a Jack of Diamonds
#
# Press any key
# Top Cards on table are
#
# Jack of Diamonds
# Ten of Clubs
#
#
# No of cards with mb are 24
# No of cards with ef,w. are 24
# No of cards on table are 4
#
#
# mb Please press enter to move a chance. You have a King of Spades
#
# Press any key
# Top Cards on table are
#
# King of Spades
# Jack of Diamonds
#
#
# No of cards with mb are 23
# No of cards with ef,w. are 24
# No of cards on table are 5
#
#
# ef,w. Please press enter to move a chance. You have a Queen of Spades
#
# Press any key
# Top Cards on table are
#
# Queen of Spades
# King of Spades
# Woohho Top two cards match ef,w. Wins this move
#
#
#
# No of cards with mb are 23
# No of cards with ef,w. are 29
# No of cards on table are 0
#
#
# mb Please press enter to move a chance. You have a Jack of Spades
#
# Press any key
# Top Cards on table are
#
# Jack of Spades
#
#
# No of cards with mb are 22
# No of cards with ef,w. are 29
# No of cards on table are 1
#
#
# ef,w. Please press enter to move a chance. You have a Seven of Hearts
#
# Press any key
# Top Cards on table are
#
# Seven of Hearts
# Jack of Spades
#
#
# No of cards with mb are 22
# No of cards with ef,w. are 28
# No of cards on table are 2
#
#
# mb Please press enter to move a chance. You have a Two of Hearts
#
# Press any key
# Top Cards on table are
#
# Two of Hearts
# Seven of Hearts
# Woohho Top two cards match mb Wins this move
#
#
#
# No of cards with mb are 24
# No of cards with ef,w. are 28
# No of cards on table are 0
#
#
# ef,w. Please press enter to move a chance. You have a Eight of Diamonds
#
# Press any key
# Top Cards on table are
#
# Eight of Diamonds
#
#
# No of cards with mb are 24
# No of cards with ef,w. are 27
# No of cards on table are 1
#
#
# mb Please press enter to move a chance. You have a Queen of Diamonds
#
# Press any key
# Top Cards on table are
#
# Queen of Diamonds
# Eight of Diamonds
# Woohho Top two cards match mb Wins this move
#
#
#
# No of cards with mb are 25
# No of cards with ef,w. are 27
# No of cards on table are 0
#
#
# ef,w. Please press enter to move a chance. You have a Ten of Diamonds
#
# Press any key
# Top Cards on table are
#
# Ten of Diamonds
#
#
# No of cards with mb are 25
# No of cards with ef,w. are 26
# No of cards on table are 1
#
#
# mb Please press enter to move a chance. You have a Six of Diamonds
#
# Press any key
# Top Cards on table are
#
# Six of Diamonds
# Ten of Diamonds
# Woohho Top two cards match mb Wins this move
#
#
#
# No of cards with mb are 26
# No of cards with ef,w. are 26
# No of cards on table are 0
#
#
# ef,w. Please press enter to move a chance. You have a Four of Spades
#
# Press any key
# Top Cards on table are
#
# Four of Spades
#
#
# No of cards with mb are 26
# No of cards with ef,w. are 25
# No of cards on table are 1
#
#
# mb Please press enter to move a chance. You have a Six of Spades
#
# Press any key
# Top Cards on table are
#
# Six of Spades
# Four of Spades
# Woohho Top two cards match mb Wins this move
#
#
#
# No of cards with mb are 27
# No of cards with ef,w. are 25
# No of cards on table are 0
#
#
# ef,w. Please press enter to move a chance. You have a King of Hearts
#
# Press any key
# Top Cards on table are
#
# King of Hearts
#
#
# No of cards with mb are 27
# No of cards with ef,w. are 24
# No of cards on table are 1
#
#
# mb Please press enter to move a chance. You have a Six of Clubs
#
# Press any key
# Top Cards on table are
#
# Six of Clubs
# King of Hearts
#
#
# No of cards with mb are 26
# No of cards with ef,w. are 24
# No of cards on table are 2
#
#
# ef,w. Please press enter to move a chance. You have a Two of Diamonds
#
# Press any key
# Top Cards on table are
#
# Two of Diamonds
# Six of Clubs
#
#
# No of cards with mb are 26
# No of cards with ef,w. are 23
# No of cards on table are 3
#
#
# mb Please press enter to move a chance. You have a Two of Spades
#
# Press any key
# Top Cards on table are
#
# Two of Spades
# Two of Diamonds
# Woohho Top two cards match mb Wins this move
#
#
#
# No of cards with mb are 29
# No of cards with ef,w. are 23
# No of cards on table are 0
#
#
# ef,w. Please press enter to move a chance. You have a Ten of Spades
#
# Press any key
# Top Cards on table are
#
# Ten of Spades
#
#
# No of cards with mb are 29
# No of cards with ef,w. are 22
# No of cards on table are 1
#
#
# mb Please press enter to move a chance. You have a Nine of Clubs
#
# Press any key
# Top Cards on table are
#
# Nine of Clubs
# Ten of Spades
#
#
# No of cards with mb are 28
# No of cards with ef,w. are 22
# No of cards on table are 2
#
#
# ef,w. Please press enter to move a chance. You have a Jack of Hearts
#
# Press any key
# Top Cards on table are
#
# Jack of Hearts
# Nine of Clubs
#
#
# No of cards with mb are 28
# No of cards with ef,w. are 21
# No of cards on table are 3
#
#
# mb Please press enter to move a chance. You have a Five of Hearts
#
# Press any key
# Top Cards on table are
#
# Five of Hearts
# Jack of Hearts
# Woohho Top two cards match mb Wins this move
#
#
#
# No of cards with mb are 31
# No of cards with ef,w. are 21
# No of cards on table are 0
#
#
# ef,w. Please press enter to move a chance. You have a Seven of Clubs
#
# Press any key
# Top Cards on table are
#
# Seven of Clubs
#
#
# No of cards with mb are 31
# No of cards with ef,w. are 20
# No of cards on table are 1
#
#
# mb Please press enter to move a chance. You have a Five of Diamonds
#
# Press any key
# Top Cards on table are
#
# Five of Diamonds
# Seven of Clubs
#
#
# No of cards with mb are 30
# No of cards with ef,w. are 20
# No of cards on table are 2
#
#
# ef,w. Please press enter to move a chance. You have a King of Clubs
#
# Press any key
# Top Cards on table are
#
# King of Clubs
# Five of Diamonds
#
#
# No of cards with mb are 30
# No of cards with ef,w. are 19
# No of cards on table are 3
#
#
# mb Please press enter to move a chance. You have a King of Diamonds
#
# Press any key
# Top Cards on table are
#
# King of Diamonds
# King of Clubs
# Woohho Top two cards match mb Wins this move
#
#
#
# No of cards with mb are 33
# No of cards with ef,w. are 19
# No of cards on table are 0
#
#
# ef,w. Please press enter to move a chance. You have a Jack of Clubs
#
# Press any key
# Top Cards on table are
#
# Jack of Clubs
#
#
# No of cards with mb are 33
# No of cards with ef,w. are 18
# No of cards on table are 1
#
#
# mb Please press enter to move a chance. You have a Five of Clubs
#
# Press any key
# Top Cards on table are
#
# Five of Clubs
# Jack of Clubs
# Woohho Top two cards match mb Wins this move
#
#
#
# No of cards with mb are 34
# No of cards with ef,w. are 18
# No of cards on table are 0
#
#
# ef,w. Please press enter to move a chance. You have a Ace of Diamonds
#
# Press any key
# Top Cards on table are
#
# Ace of Diamonds
#
#
# No of cards with mb are 34
# No of cards with ef,w. are 17
# No of cards on table are 1
#
#
# mb Please press enter to move a chance. You have a Ten of Hearts
# Press any key
# Top Cards on table are
#
# Ten of Hearts
# Ace of Diamonds
#
#
# No of cards with mb are 33
# No of cards with ef,w. are 17
# No of cards on table are 2
#
#
# ef,w. Please press enter to move a chance. You have a Five of Spades
#
# Press any key
# Top Cards on table are
#
# Five of Spades
# Ten of Hearts
#
#
# No of cards with mb are 33
# No of cards with ef,w. are 16
# No of cards on table are 3
#
#
# mb Please press enter to move a chance. You have a Three of Spades
#
# Press any key
# Top Cards on table are
#
# Three of Spades
# Five of Spades
# Woohho Top two cards match mb Wins this move
#
#
#
# No of cards with mb are 36
# No of cards with ef,w. are 16
# No of cards on table are 0
#
#
# ef,w. Please press enter to move a chance. You have a Queen of Hearts
#
# Press any key
# Top Cards on table are
#
# Queen of Hearts
#
#
# No of cards with mb are 36
# No of cards with ef,w. are 15
# No of cards on table are 1
#
#
# mb Please press enter to move a chance. You have a Ace of Spades
#
# Press any key
# Top Cards on table are
#
# Ace of Spades
# Queen of Hearts
#
#
# No of cards with mb are 35
# No of cards with ef,w. are 15
# No of cards on table are 2
#
#
# ef,w. Please press enter to move a chance. You have a Four of Hearts
#
# Press any key
# Top Cards on table are
#
# Four of Hearts
# Ace of Spades
#
#
# No of cards with mb are 35
# No of cards with ef,w. are 14
# No of cards on table are 3
#
#
# mb Please press enter to move a chance. You have a Nine of Hearts
#
# Press any key
# Top Cards on table are
#
# Nine of Hearts
# Four of Hearts
# Woohho Top two cards match mb Wins this move
#
#
#
# No of cards with mb are 38
# No of cards with ef,w. are 14
# No of cards on table are 0
#
#
# ef,w. Please press enter to move a chance. You have a Eight of Spades
#
# Press any key
# Top Cards on table are
#
# Eight of Spades
#
#
# No of cards with mb are 38
# No of cards with ef,w. are 13
# No of cards on table are 1
#
#
# mb Please press enter to move a chance. You have a Seven of Diamonds
#
# Press any key
# Top Cards on table are
#
# Seven of Diamonds
# Eight of Spades
#
#
# No of cards with mb are 37
# No of cards with ef,w. are 13
# No of cards on table are 2
#
#
# ef,w. Please press enter to move a chance. You have a Six of Hearts
#
# Press any key
# Top Cards on table are
#
# Six of Hearts
# Seven of Diamonds
#
#
# No of cards with mb are 37
# No of cards with ef,w. are 12
# No of cards on table are 3
#
#
# mb Please press enter to move a chance. You have a Nine of Diamonds
#
# Press any key
# Top Cards on table are
#
# Nine of Diamonds
# Six of Hearts
#
#
# No of cards with mb are 36
# No of cards with ef,w. are 12
# No of cards on table are 4
#
#
# ef,w. Please press enter to move a chance. You have a Eight of Hearts
#
# Press any key
# Top Cards on table are
#
# Eight of Hearts
# Nine of Diamonds
#
#
# No of cards with mb are 36
# No of cards with ef,w. are 11
# No of cards on table are 5
#
#
# mb Please press enter to move a chance. You have a Two of Clubs
#
# Press any key
# Top Cards on table are
#
# Two of Clubs
# Eight of Hearts
#
#
# No of cards with mb are 35
# No of cards with ef,w. are 11
# No of cards on table are 6
#
#
# ef,w. Please press enter to move a chance. You have a Ace of Hearts
#
# Press any key
# Top Cards on table are
#
# Ace of Hearts
# Two of Clubs
#
#
# No of cards with mb are 35
# No of cards with ef,w. are 10
# No of cards on table are 7
#
#
# mb Please press enter to move a chance. You have a Three of Diamonds
#
# Press any key
# Top Cards on table are
#
# Three of Diamonds
# Ace of Hearts
#
#
# No of cards with mb are 34
# No of cards with ef,w. are 10
# No of cards on table are 8
#
#
# ef,w. Please press enter to move a chance. You have a Three of Hearts
#
# Press any key
# Top Cards on table are
#
# Three of Hearts
# Three of Diamonds
# Woohho Top two cards match ef,w. Wins this move
#
#
#
# No of cards with mb are 34
# No of cards with ef,w. are 18
# No of cards on table are 0
#
#
# mb Please press enter to move a chance. You have a Queen of Clubs
#
# Press any key
# Top Cards on table are
#
# Queen of Clubs
#
#
# No of cards with mb are 33
# No of cards with ef,w. are 18
# No of cards on table are 1
#
#
# ef,w. Please press enter to move a chance. You have a Seven of Spades
#
# Press any key
# Top Cards on table are
#
# Seven of Spades
# Queen of Clubs
#
#
# No of cards with mb are 33
# No of cards with ef,w. are 17
# No of cards on table are 2
#
#
# mb Please press enter to move a chance. You have a Four of Clubs
#
# Press any key
# Top Cards on table are
#
# Four of Clubs
# Seven of Spades
#
#
# No of cards with mb are 32
# No of cards with ef,w. are 17
# No of cards on table are 3
#
#
# ef,w. Please press enter to move a chance. You have a Eight of Clubs
#
# Press any key
# Top Cards on table are
#
# Eight of Clubs
# Four of Clubs
# Woohho Top two cards match ef,w. Wins this move
#
#
#
# No of cards with mb are 32
# No of cards with ef,w. are 20
# No of cards on table are 0
#
#
# mb Please press enter to move a chance. You have a Ace of Clubs
#
# Press any key
# Top Cards on table are
#
# Ace of Clubs
#
#
# No of cards with mb are 31
# No of cards with ef,w. are 20
# No of cards on table are 1
#
#
# ef,w. Please press enter to move a chance. You have a Nine of Spades
#
# Press any key
# Top Cards on table are
#
# Nine of Spades
# Ace of Clubs
#
#
# No of cards with mb are 31
# No of cards with ef,w. are 19
# No of cards on table are 2
#
#
# mb Please press enter to move a chance. You have a Two of Hearts
#
# Press any key
# Top Cards on table are
#
# Two of Hearts
# Nine of Spades
#
#
# No of cards with mb are 30
# No of cards with ef,w. are 19
# No of cards on table are 3
#
#
# ef,w. Please press enter to move a chance. You have a Queen of Spades
#
# Press any key
# Top Cards on table are
#
# Queen of Spades
# Two of Hearts
#
#
# No of cards with mb are 30
# No of cards with ef,w. are 18
# No of cards on table are 4
#
#
# mb Please press enter to move a chance. You have a Seven of Hearts
#
# Press any key
# Top Cards on table are
#
# Seven of Hearts
# Queen of Spades
#
#
# No of cards with mb are 29
# No of cards with ef,w. are 18
# No of cards on table are 5
#
#
# ef,w. Please press enter to move a chance. You have a King of Spades
#
# Press any key
# Top Cards on table are
#
# King of Spades
# Seven of Hearts
#
#
# No of cards with mb are 29
# No of cards with ef,w. are 17
# No of cards on table are 6
#
#
# mb Please press enter to move a chance. You have a Jack of Spades
#
# Press any key
# Top Cards on table are
#
# Jack of Spades
# King of Spades
# Woohho Top two cards match mb Wins this move
#
#
#
# No of cards with mb are 35
# No of cards with ef,w. are 17
# No of cards on table are 0
#
#
# ef,w. Please press enter to move a chance. You have a Jack of Diamonds
#
# Press any key
# Top Cards on table are
#
# Jack of Diamonds
#
#
# No of cards with mb are 35
# No of cards with ef,w. are 16
# No of cards on table are 1
#
#
# mb Please press enter to move a chance. You have a Queen of Diamonds
#
# Press any key
# Top Cards on table are
#
# Queen of Diamonds
# Jack of Diamonds
# Woohho Top two cards match mb Wins this move
#
#
#
# No of cards with mb are 36
# No of cards with ef,w. are 16
# No of cards on table are 0
#
#
# ef,w. Please press enter to move a chance. You have a Ten of Clubs
#
# Press any key
# Top Cards on table are
#
# Ten of Clubs
#
#
# No of cards with mb are 36
# No of cards with ef,w. are 15
# No of cards on table are 1
#
#
# mb Please press enter to move a chance. You have a Eight of Diamonds
#
# Press any key
# Top Cards on table are
#
# Eight of Diamonds
# Ten of Clubs
#
#
# No of cards with mb are 35
# No of cards with ef,w. are 15
# No of cards on table are 2
#
#
# ef,w. Please press enter to move a chance. You have a Four of Diamonds
#
# Press any key
# Top Cards on table are
#
# Four of Diamonds
# Eight of Diamonds
# Woohho Top two cards match ef,w. Wins this move
#
#
#
# No of cards with mb are 35
# No of cards with ef,w. are 17
# No of cards on table are 0
#
#
# mb Please press enter to move a chance. You have a Six of Diamonds
#
# Press any key
# Top Cards on table are
#
# Six of Diamonds
#
#
# No of cards with mb are 34
# No of cards with ef,w. are 17
# No of cards on table are 1
#
#
# ef,w. Please press enter to move a chance. You have a Three of Clubs
#
# Press any key
# Top Cards on table are
#
# Three of Clubs
# Six of Diamonds
#
#
# No of cards with mb are 34
# No of cards with ef,w. are 16
# No of cards on table are 2
#
#
# mb Please press enter to move a chance. You have a Ten of Diamonds
#
# Press any key
# Top Cards on table are
#
# Ten of Diamonds
# Three of Clubs
#
#
# No of cards with mb are 33
# No of cards with ef,w. are 16
# No of cards on table are 3
#
#
# ef,w. Please press enter to move a chance. You have a Three of Hearts
# Press any key
# Top Cards on table are
#
# Three of Hearts
# Ten of Diamonds
#
#
# No of cards with mb are 33
# No of cards with ef,w. are 15
# No of cards on table are 4
#
#
# mb Please press enter to move a chance. You have a Six of Spades
#
# Press any key
# Top Cards on table are
#
# Six of Spades
# Three of Hearts
#
#
# No of cards with mb are 32
# No of cards with ef,w. are 15
# No of cards on table are 5
#
#
# ef,w. Please press enter to move a chance. You have a Three of Diamonds
#
# Press any key
# Top Cards on table are
#
# Three of Diamonds
# Six of Spades
#
#
# No of cards with mb are 32
# No of cards with ef,w. are 14
# No of cards on table are 6
#
#
# mb Please press enter to move a chance. You have a Four of Spades
#
# Press any key
# Top Cards on table are
#
# Four of Spades
# Three of Diamonds
#
#
# No of cards with mb are 31
# No of cards with ef,w. are 14
# No of cards on table are 7
#
#
# ef,w. Please press enter to move a chance. You have a Ace of Hearts
#
# Press any key
# Top Cards on table are
#
# Ace of Hearts
# Four of Spades
#
#
# No of cards with mb are 31
# No of cards with ef,w. are 13
# No of cards on table are 8
#
#
# mb Please press enter to move a chance. You have a Two of Spades
#
# Press any key
# Top Cards on table are
#
# Two of Spades
# Ace of Hearts
#
#
# No of cards with mb are 30
# No of cards with ef,w. are 13
# No of cards on table are 9
#
#
# ef,w. Please press enter to move a chance. You have a Two of Clubs
#
# Press any key
# Top Cards on table are
#
# Two of Clubs
# Two of Spades
# Woohho Top two cards match ef,w. Wins this move
#
#
#
# No of cards with mb are 30
# No of cards with ef,w. are 22
# No of cards on table are 0
#
#
# mb Please press enter to move a chance. You have a Two of Diamonds
#
# Press any key
# Top Cards on table are
#
# Two of Diamonds
#
#
# No of cards with mb are 29
# No of cards with ef,w. are 22
# No of cards on table are 1
#
#
# ef,w. Please press enter to move a chance. You have a Eight of Hearts
#
# Press any key
# Top Cards on table are
#
# Eight of Hearts
# Two of Diamonds
#
#
# No of cards with mb are 29
# No of cards with ef,w. are 21
# No of cards on table are 2
#
#
# mb Please press enter to move a chance. You have a Six of Clubs
#
# Press any key
# Top Cards on table are
#
# Six of Clubs
# Eight of Hearts
#
#
# No of cards with mb are 28
# No of cards with ef,w. are 21
# No of cards on table are 3
#
#
# ef,w. Please press enter to move a chance. You have a Nine of Diamonds
#
# Press any key
# Top Cards on table are
#
# Nine of Diamonds
# Six of Clubs
#
#
# No of cards with mb are 28
# No of cards with ef,w. are 20
# No of cards on table are 4
#
#
# mb Please press enter to move a chance. You have a King of Hearts
#
# Press any key
# Top Cards on table are
#
# King of Hearts
# Nine of Diamonds
#
#
# No of cards with mb are 27
# No of cards with ef,w. are 20
# No of cards on table are 5
#
#
# ef,w. Please press enter to move a chance. You have a Six of Hearts
#
# Press any key
# Top Cards on table are
#
# Six of Hearts
# King of Hearts
# Woohho Top two cards match ef,w. Wins this move
#
#
#
# No of cards with mb are 27
# No of cards with ef,w. are 25
# No of cards on table are 0
#
#
# mb Please press enter to move a chance. You have a Five of Hearts
#
# Press any key
# Top Cards on table are
#
# Five of Hearts
#
#
# No of cards with mb are 26
# No of cards with ef,w. are 25
# No of cards on table are 1
#
#
# ef,w. Please press enter to move a chance. You have a Seven of Diamonds
#
# Press any key
# Top Cards on table are
#
# Seven of Diamonds
# Five of Hearts
#
#
# No of cards with mb are 26
# No of cards with ef,w. are 24
# No of cards on table are 2
#
#
# mb Please press enter to move a chance. You have a Jack of Hearts
#
# Press any key
# Top Cards on table are
#
# Jack of Hearts
# Seven of Diamonds
#
#
# No of cards with mb are 25
# No of cards with ef,w. are 24
# No of cards on table are 3
#
#
# ef,w. Please press enter to move a chance. You have a Eight of Spades
#
# Press any key
# Top Cards on table are
#
# Eight of Spades
# Jack of Hearts
#
#
# No of cards with mb are 25
# No of cards with ef,w. are 23
# No of cards on table are 4
#
#
# mb Please press enter to move a chance. You have a Nine of Clubs
#
# Press any key
# Top Cards on table are
#
# Nine of Clubs
# Eight of Spades
#
#
# No of cards with mb are 24
# No of cards with ef,w. are 23
# No of cards on table are 5
#
#
# ef,w. Please press enter to move a chance. You have a Eight of Clubs
#
# Press any key
# Top Cards on table are
#
# Eight of Clubs
# Nine of Clubs
# Woohho Top two cards match ef,w. Wins this move
#
#
#
# No of cards with mb are 24
# No of cards with ef,w. are 28
# No of cards on table are 0
#
#
# mb Please press enter to move a chance. You have a Ten of Spades
#
# Press any key
# Top Cards on table are
#
# Ten of Spades
#
#
# No of cards with mb are 23
# No of cards with ef,w. are 28
# No of cards on table are 1
#
#
# ef,w. Please press enter to move a chance. You have a Four of Clubs
#
# Press any key
# Top Cards on table are
#
# Four of Clubs
# Ten of Spades
#
#
# No of cards with mb are 23
# No of cards with ef,w. are 27
# No of cards on table are 2
#
#
# mb Please press enter to move a chance. You have a King of Diamonds
#
# Press any key
# Top Cards on table are
#
# King of Diamonds
# Four of Clubs
#
#
# No of cards with mb are 22
# No of cards with ef,w. are 27
# No of cards on table are 3
#
#
# ef,w. Please press enter to move a chance. You have a Seven of Spades
#
# Press any key
# Top Cards on table are
#
# Seven of Spades
# King of Diamonds
#
#
# No of cards with mb are 22
# No of cards with ef,w. are 26
# No of cards on table are 4
#
#
# mb Please press enter to move a chance. You have a King of Clubs
#
# Press any key
# Top Cards on table are
#
# King of Clubs
# Seven of Spades
#
#
# No of cards with mb are 21
# No of cards with ef,w. are 26
# No of cards on table are 5
#
#
# ef,w. Please press enter to move a chance. You have a Queen of Clubs
#
# Press any key
# Top Cards on table are
#
# Queen of Clubs
# King of Clubs
# Woohho Top two cards match ef,w. Wins this move
#
#
#
# No of cards with mb are 21
# No of cards with ef,w. are 31
# No of cards on table are 0
#
#
# mb Please press enter to move a chance. You have a Five of Diamonds
#
# Press any key
# Top Cards on table are
#
# Five of Diamonds
#
#
# No of cards with mb are 20
# No of cards with ef,w. are 31
# No of cards on table are 1
#
#
# ef,w. Please press enter to move a chance. You have a Four of Diamonds
#
# Press any key
# Top Cards on table are
#
# Four of Diamonds
# Five of Diamonds
# Woohho Top two cards match ef,w. Wins this move
#
#
#
# No of cards with mb are 20
# No of cards with ef,w. are 32
# No of cards on table are 0
#
#
# mb Please press enter to move a chance. You have a Seven of Clubs
#
# Press any key
# Top Cards on table are
#
# Seven of Clubs
#
#
# No of cards with mb are 19
# No of cards with ef,w. are 32
# No of cards on table are 1
#
#
# ef,w. Please press enter to move a chance. You have a Eight of Diamonds
#
# Press any key
# Top Cards on table are
#
# Eight of Diamonds
# Seven of Clubs
#
#
# No of cards with mb are 19
# No of cards with ef,w. are 31
# No of cards on table are 2
#
#
# mb Please press enter to move a chance. You have a Five of Clubs
#
# Press any key
# Top Cards on table are
#
# Five of Clubs
# Eight of Diamonds
#
#
# No of cards with mb are 18
# No of cards with ef,w. are 31
# No of cards on table are 3
#
#
# ef,w. Please press enter to move a chance. You have a Ten of Clubs
#
# Press any key
# Top Cards on table are
#
# Ten of Clubs
# Five of Clubs
# Woohho Top two cards match ef,w. Wins this move
#
#
#
# No of cards with mb are 18
# No of cards with ef,w. are 34
# No of cards on table are 0
#
#
# mb Please press enter to move a chance. You have a Jack of Clubs
#
# Press any key
# Top Cards on table are
#
# Jack of Clubs
#
#
# No of cards with mb are 17
# No of cards with ef,w. are 34
# No of cards on table are 1
#
#
# ef,w. Please press enter to move a chance. You have a Two of Clubs
#
# Press any key
# Top Cards on table are
#
# Two of Clubs
# Jack of Clubs
# Woohho Top two cards match ef,w. Wins this move
#
#
#
# No of cards with mb are 17
# No of cards with ef,w. are 35
# No of cards on table are 0
#
#
# mb Please press enter to move a chance. You have a Three of Spades
#
# Press any key
# Top Cards on table are
#
# Three of Spades
#
#
# No of cards with mb are 16
# No of cards with ef,w. are 35
# No of cards on table are 1
#
#
# ef,w. Please press enter to move a chance. You have a Two of Spades
#
# Press any key
# Top Cards on table are
#
# Two of Spades
# Three of Spades
# Woohho Top two cards match ef,w. Wins this move
#
#
#
# No of cards with mb are 16
# No of cards with ef,w. are 36
# No of cards on table are 0
#
#
# mb Please press enter to move a chance. You have a Five of Spades
# Press any key
# Top Cards on table are
#
# Five of Spades
#
#
# No of cards with mb are 15
# No of cards with ef,w. are 36
# No of cards on table are 1
#
#
# ef,w. Please press enter to move a chance. You have a Ace of Hearts
#
# Press any key
# Top Cards on table are
#
# Ace of Hearts
# Five of Spades
#
#
# No of cards with mb are 15
# No of cards with ef,w. are 35
# No of cards on table are 2
#
#
# mb Please press enter to move a chance. You have a Ten of Hearts
#
# Press any key
# Top Cards on table are
#
# Ten of Hearts
# Ace of Hearts
# Woohho Top two cards match mb Wins this move
#
#
#
# No of cards with mb are 17
# No of cards with ef,w. are 35
# No of cards on table are 0
#
#
# ef,w. Please press enter to move a chance. You have a Four of Spades
#
# Press any key
# Top Cards on table are
#
# Four of Spades
#
#
# No of cards with mb are 17
# No of cards with ef,w. are 34
# No of cards on table are 1
#
#
# mb Please press enter to move a chance. You have a Ace of Diamonds
#
# Press any key
# Top Cards on table are
#
# Ace of Diamonds
# Four of Spades
#
#
# No of cards with mb are 16
# No of cards with ef,w. are 34
# No of cards on table are 2
#
#
# ef,w. Please press enter to move a chance. You have a Three of Diamonds
#
# Press any key
# Top Cards on table are
#
# Three of Diamonds
# Ace of Diamonds
# Woohho Top two cards match ef,w. Wins this move
#
#
#
# No of cards with mb are 16
# No of cards with ef,w. are 36
# No of cards on table are 0
#
#
# mb Please press enter to move a chance. You have a Nine of Hearts
#
# Press any key
# Top Cards on table are
#
# Nine of Hearts
#
#
# No of cards with mb are 15
# No of cards with ef,w. are 36
# No of cards on table are 1
#
#
# ef,w. Please press enter to move a chance. You have a Six of Spades
#
# Press any key
# Top Cards on table are
#
# Six of Spades
# Nine of Hearts
#
#
# No of cards with mb are 15
# No of cards with ef,w. are 35
# No of cards on table are 2
#
#
# mb Please press enter to move a chance. You have a Four of Hearts
#
# Press any key
# Top Cards on table are
#
# Four of Hearts
# Six of Spades
#
#
# No of cards with mb are 14
# No of cards with ef,w. are 35
# No of cards on table are 3
#
#
# ef,w. Please press enter to move a chance. You have a Three of Hearts
#
# Press any key
# Top Cards on table are
#
# Three of Hearts
# Four of Hearts
# Woohho Top two cards match ef,w. Wins this move
#
#
#
# No of cards with mb are 14
# No of cards with ef,w. are 38
# No of cards on table are 0
#
#
# mb Please press enter to move a chance. You have a Ace of Spades
#
# Press any key
# Top Cards on table are
#
# Ace of Spades
#
#
# No of cards with mb are 13
# No of cards with ef,w. are 38
# No of cards on table are 1
#
#
# ef,w. Please press enter to move a chance. You have a Ten of Diamonds
#
# Press any key
# Top Cards on table are
#
# Ten of Diamonds
# Ace of Spades
#
#
# No of cards with mb are 13
# No of cards with ef,w. are 37
# No of cards on table are 2
#
#
# mb Please press enter to move a chance. You have a Queen of Hearts
#
# Press any key
# Top Cards on table are
#
# Queen of Hearts
# Ten of Diamonds
#
#
# No of cards with mb are 12
# No of cards with ef,w. are 37
# No of cards on table are 3
#
#
# ef,w. Please press enter to move a chance. You have a Three of Clubs
#
# Press any key
# Top Cards on table are
#
# Three of Clubs
# Queen of Hearts
#
#
# No of cards with mb are 12
# No of cards with ef,w. are 36
# No of cards on table are 4
#
#
# mb Please press enter to move a chance. You have a Jack of Spades
#
# Press any key
# Top Cards on table are
#
# Jack of Spades
# Three of Clubs
#
#
# No of cards with mb are 11
# No of cards with ef,w. are 36
# No of cards on table are 5
#
#
# ef,w. Please press enter to move a chance. You have a Six of Diamonds
#
# Press any key
# Top Cards on table are
#
# Six of Diamonds
# Jack of Spades
#
#
# No of cards with mb are 11
# No of cards with ef,w. are 35
# No of cards on table are 6
#
#
# mb Please press enter to move a chance. You have a King of Spades
#
# Press any key
# Top Cards on table are
#
# King of Spades
# Six of Diamonds
#
#
# No of cards with mb are 10
# No of cards with ef,w. are 35
# No of cards on table are 7
#
#
# ef,w. Please press enter to move a chance. You have a Six of Hearts
#
# Press any key
# Top Cards on table are
#
# Six of Hearts
# King of Spades
#
#
# No of cards with mb are 10
# No of cards with ef,w. are 34
# No of cards on table are 8
#
#
# mb Please press enter to move a chance. You have a Seven of Hearts
#
# Press any key
# Top Cards on table are
#
# Seven of Hearts
# Six of Hearts
# Woohho Top two cards match mb Wins this move
#
#
#
# No of cards with mb are 18
# No of cards with ef,w. are 34
# No of cards on table are 0
#
#
# ef,w. Please press enter to move a chance. You have a King of Hearts
#
# Press any key
# Top Cards on table are
#
# King of Hearts
#
#
# No of cards with mb are 18
# No of cards with ef,w. are 33
# No of cards on table are 1
#
#
# mb Please press enter to move a chance. You have a Queen of Spades
#
# Press any key
# Top Cards on table are
#
# Queen of Spades
# King of Hearts
#
#
# No of cards with mb are 17
# No of cards with ef,w. are 33
# No of cards on table are 2
#
#
# ef,w. Please press enter to move a chance. You have a Nine of Diamonds
#
# Press any key
# Top Cards on table are
#
# Nine of Diamonds
# Queen of Spades
#
#
# No of cards with mb are 17
# No of cards with ef,w. are 32
# No of cards on table are 3
#
#
# mb Please press enter to move a chance. You have a Two of Hearts
#
# Press any key
# Top Cards on table are
#
# Two of Hearts
# Nine of Diamonds
#
#
# No of cards with mb are 16
# No of cards with ef,w. are 32
# No of cards on table are 4
#
#
# ef,w. Please press enter to move a chance. You have a Six of Clubs
#
# Press any key
# Top Cards on table are
#
# Six of Clubs
# Two of Hearts
#
#
# No of cards with mb are 16
# No of cards with ef,w. are 31
# No of cards on table are 5
#
#
# mb Please press enter to move a chance. You have a Nine of Spades
#
# Press any key
# Top Cards on table are
#
# Nine of Spades
# Six of Clubs
#
#
# No of cards with mb are 15
# No of cards with ef,w. are 31
# No of cards on table are 6
#
#
# ef,w. Please press enter to move a chance. You have a Eight of Hearts
#
# Press any key
# Top Cards on table are
#
# Eight of Hearts
# Nine of Spades
#
#
# No of cards with mb are 15
# No of cards with ef,w. are 30
# No of cards on table are 7
#
#
# mb Please press enter to move a chance. You have a Ace of Clubs
#
# Press any key
# Top Cards on table are
#
# Ace of Clubs
# Eight of Hearts
#
#
# No of cards with mb are 14
# No of cards with ef,w. are 30
# No of cards on table are 8
#
#
# ef,w. Please press enter to move a chance. You have a Two of Diamonds
#
# Press any key
# Top Cards on table are
#
# Two of Diamonds
# Ace of Clubs
#
#
# No of cards with mb are 14
# No of cards with ef,w. are 29
# No of cards on table are 9
#
#
# mb Please press enter to move a chance. You have a Queen of Diamonds
#
# Press any key
# Top Cards on table are
#
# Queen of Diamonds
# Two of Diamonds
# Woohho Top two cards match mb Wins this move
#
#
#
# No of cards with mb are 23
# No of cards with ef,w. are 29
# No of cards on table are 0
#
#
# ef,w. Please press enter to move a chance. You have a Eight of Clubs
#
# Press any key
# Top Cards on table are
#
# Eight of Clubs
#
#
# No of cards with mb are 23
# No of cards with ef,w. are 28
# No of cards on table are 1
#
#
# mb Please press enter to move a chance. You have a Jack of Diamonds
#
# Press any key
# Top Cards on table are
#
# Jack of Diamonds
# Eight of Clubs
#
#
# No of cards with mb are 22
# No of cards with ef,w. are 28
# No of cards on table are 2
#
#
# ef,w. Please press enter to move a chance. You have a Nine of Clubs
#
# Press any key
# Top Cards on table are
#
# Nine of Clubs
# Jack of Diamonds
#
#
# No of cards with mb are 22
# No of cards with ef,w. are 27
# No of cards on table are 3
#
#
# mb Please press enter to move a chance. You have a Ten of Hearts
#
# Press any key
# Top Cards on table are
#
# Ten of Hearts
# Nine of Clubs
#
#
# No of cards with mb are 21
# No of cards with ef,w. are 27
# No of cards on table are 4
#
#
# ef,w. Please press enter to move a chance. You have a Eight of Spades
#
# Press any key
# Top Cards on table are
#
# Eight of Spades
# Ten of Hearts
#
#
# No of cards with mb are 21
# No of cards with ef,w. are 26
# No of cards on table are 5
#
#
# mb Please press enter to move a chance. You have a Ace of Hearts
#
# Press any key
# Top Cards on table are
#
# Ace of Hearts
# Eight of Spades
#
#
# No of cards with mb are 20
# No of cards with ef,w. are 26
# No of cards on table are 6
#
#
# ef,w. Please press enter to move a chance. You have a Jack of Hearts
#
# Press any key
# Top Cards on table are
#
# Jack of Hearts
# Ace of Hearts
# Woohho Top two cards match ef,w. Wins this move
#
#
#
# No of cards with mb are 20
# No of cards with ef,w. are 32
# No of cards on table are 0
#
#
# mb Please press enter to move a chance. You have a Five of Spades
# Press any key
# Top Cards on table are
#
# Five of Spades
#
#
# No of cards with mb are 19
# No of cards with ef,w. are 32
# No of cards on table are 1
#
#
# ef,w. Please press enter to move a chance. You have a Seven of Diamonds
#
# Press any key
# Top Cards on table are
#
# Seven of Diamonds
# Five of Spades
#
#
# No of cards with mb are 19
# No of cards with ef,w. are 31
# No of cards on table are 2
#
#
# mb Please press enter to move a chance. You have a Seven of Hearts
#
# Press any key
# Top Cards on table are
#
# Seven of Hearts
# Seven of Diamonds
# Woohho Top two cards match mb Wins this move
#
#
#
# No of cards with mb are 21
# No of cards with ef,w. are 31
# No of cards on table are 0
#
#
# ef,w. Please press enter to move a chance. You have a Five of Hearts
#
# Press any key
# Top Cards on table are
#
# Five of Hearts
#
#
# No of cards with mb are 21
# No of cards with ef,w. are 30
# No of cards on table are 1
#
#
# mb Please press enter to move a chance. You have a Six of Hearts
#
# Press any key
# Top Cards on table are
#
# Six of Hearts
# Five of Hearts
# Woohho Top two cards match mb Wins this move
#
#
#
# No of cards with mb are 22
# No of cards with ef,w. are 30
# No of cards on table are 0
#
#
# ef,w. Please press enter to move a chance. You have a Queen of Clubs
#
# Press any key
# Top Cards on table are
#
# Queen of Clubs
#
#
# No of cards with mb are 22
# No of cards with ef,w. are 29
# No of cards on table are 1
#
#
# mb Please press enter to move a chance. You have a King of Spades
#
# Press any key
# Top Cards on table are
#
# King of Spades
# Queen of Clubs
#
#
# No of cards with mb are 21
# No of cards with ef,w. are 29
# No of cards on table are 2
#
#
# ef,w. Please press enter to move a chance. You have a King of Clubs
#
# Press any key
# Top Cards on table are
#
# King of Clubs
# King of Spades
# Woohho Top two cards match ef,w. Wins this move
#
#
#
# No of cards with mb are 21
# No of cards with ef,w. are 31
# No of cards on table are 0
#
#
# mb Please press enter to move a chance. You have a Six of Diamonds
#
# Press any key
# Top Cards on table are
#
# Six of Diamonds
#
#
# No of cards with mb are 20
# No of cards with ef,w. are 31
# No of cards on table are 1
#
#
# ef,w. Please press enter to move a chance. You have a Seven of Spades
#
# Press any key
# Top Cards on table are
#
# Seven of Spades
# Six of Diamonds
#
#
# No of cards with mb are 20
# No of cards with ef,w. are 30
# No of cards on table are 2
#
#
# mb Please press enter to move a chance. You have a Jack of Spades
#
# Press any key
# Top Cards on table are
#
# Jack of Spades
# Seven of Spades
# Woohho Top two cards match mb Wins this move
#
#
#
# No of cards with mb are 22
# No of cards with ef,w. are 30
# No of cards on table are 0
#
#
# ef,w. Please press enter to move a chance. You have a King of Diamonds
#
# Press any key
# Top Cards on table are
#
# King of Diamonds
#
#
# No of cards with mb are 22
# No of cards with ef,w. are 29
# No of cards on table are 1
#
#
# mb Please press enter to move a chance. You have a Three of Clubs
#
# Press any key
# Top Cards on table are
#
# Three of Clubs
# King of Diamonds
#
#
# No of cards with mb are 21
# No of cards with ef,w. are 29
# No of cards on table are 2
#
#
# ef,w. Please press enter to move a chance. You have a Four of Clubs
#
# Press any key
# Top Cards on table are
#
# Four of Clubs
# Three of Clubs
# Woohho Top two cards match ef,w. Wins this move
#
#
#
# No of cards with mb are 21
# No of cards with ef,w. are 31
# No of cards on table are 0
#
#
# mb Please press enter to move a chance. You have a Queen of Hearts
#
# Press any key
# Top Cards on table are
#
# Queen of Hearts
#
#
# No of cards with mb are 20
# No of cards with ef,w. are 31
# No of cards on table are 1
#
#
# ef,w. Please press enter to move a chance. You have a Ten of Spades
#
# Press any key
# Top Cards on table are
#
# Ten of Spades
# Queen of Hearts
#
#
# No of cards with mb are 20
# No of cards with ef,w. are 30
# No of cards on table are 2
#
#
# mb Please press enter to move a chance. You have a Ten of Diamonds
#
# Press any key
# Top Cards on table are
#
# Ten of Diamonds
# Ten of Spades
# Woohho Top two cards match mb Wins this move
#
#
#
# No of cards with mb are 22
# No of cards with ef,w. are 30
# No of cards on table are 0
#
#
# ef,w. Please press enter to move a chance. You have a Four of Diamonds
#
# Press any key
# Top Cards on table are
#
# Four of Diamonds
#
#
# No of cards with mb are 22
# No of cards with ef,w. are 29
# No of cards on table are 1
#
#
# mb Please press enter to move a chance. You have a Ace of Spades
#
# Press any key
# Top Cards on table are
#
# Ace of Spades
# Four of Diamonds
#
#
# No of cards with mb are 21
# No of cards with ef,w. are 29
# No of cards on table are 2
#
#
# ef,w. Please press enter to move a chance. You have a Five of Diamonds
#
# Press any key
# Top Cards on table are
#
# Five of Diamonds
# Ace of Spades
#
#
# No of cards with mb are 21
# No of cards with ef,w. are 28
# No of cards on table are 3
#
#
# mb Please press enter to move a chance. You have a Queen of Diamonds
#
# Press any key
# Top Cards on table are
#
# Queen of Diamonds
# Five of Diamonds
# Woohho Top two cards match mb Wins this move
#
#
#
# No of cards with mb are 24
# No of cards with ef,w. are 28
# No of cards on table are 0
#
#
# ef,w. Please press enter to move a chance. You have a Ten of Clubs
#
# Press any key
# Top Cards on table are
#
# Ten of Clubs
#
#
# No of cards with mb are 24
# No of cards with ef,w. are 27
# No of cards on table are 1
#
#
# mb Please press enter to move a chance. You have a Two of Diamonds
#
# Press any key
# Top Cards on table are
#
# Two of Diamonds
# Ten of Clubs
#
#
# No of cards with mb are 23
# No of cards with ef,w. are 27
# No of cards on table are 2
#
#
# ef,w. Please press enter to move a chance. You have a Five of Clubs
#
# Press any key
# Top Cards on table are
#
# Five of Clubs
# Two of Diamonds
#
#
# No of cards with mb are 23
# No of cards with ef,w. are 26
# No of cards on table are 3
#
#
# mb Please press enter to move a chance. You have a Ace of Clubs
#
# Press any key
# Top Cards on table are
#
# Ace of Clubs
# Five of Clubs
# Woohho Top two cards match mb Wins this move
#
#
#
# No of cards with mb are 26
# No of cards with ef,w. are 26
# No of cards on table are 0
#
#
# ef,w. Please press enter to move a chance. You have a Eight of Diamonds
#
# Press any key
# Top Cards on table are
#
# Eight of Diamonds
#
#
# No of cards with mb are 26
# No of cards with ef,w. are 25
# No of cards on table are 1
#
#
# mb Please press enter to move a chance. You have a Eight of Hearts
#
# Press any key
# Top Cards on table are
#
# Eight of Hearts
# Eight of Diamonds
# Woohho Top two cards match mb Wins this move
#
#
#
# No of cards with mb are 27
# No of cards with ef,w. are 25
# No of cards on table are 0
#
#
# ef,w. Please press enter to move a chance. You have a Seven of Clubs
#
# Press any key
# Top Cards on table are
#
# Seven of Clubs
#
#
# No of cards with mb are 27
# No of cards with ef,w. are 24
# No of cards on table are 1
#
#
# mb Please press enter to move a chance. You have a Nine of Spades
#
# Press any key
# Top Cards on table are
#
# Nine of Spades
# Seven of Clubs
#
#
# No of cards with mb are 26
# No of cards with ef,w. are 24
# No of cards on table are 2
#
#
# ef,w. Please press enter to move a chance. You have a Two of Clubs
#
# Press any key
# Top Cards on table are
#
# Two of Clubs
# Nine of Spades
#
#
# No of cards with mb are 26
# No of cards with ef,w. are 23
# No of cards on table are 3
#
#
# mb Please press enter to move a chance. You have a Six of Clubs
#
# Press any key
# Top Cards on table are
#
# Six of Clubs
# Two of Clubs
# Woohho Top two cards match mb Wins this move
#
#
#
# No of cards with mb are 29
# No of cards with ef,w. are 23
# No of cards on table are 0
#
#
# ef,w. Please press enter to move a chance. You have a Jack of Clubs
#
# Press any key
# Top Cards on table are
#
# Jack of Clubs
#
#
# No of cards with mb are 29
# No of cards with ef,w. are 22
# No of cards on table are 1
#
#
# mb Please press enter to move a chance. You have a Two of Hearts
#
# Press any key
# Top Cards on table are
#
# Two of Hearts
# Jack of Clubs
#
#
# No of cards with mb are 28
# No of cards with ef,w. are 22
# No of cards on table are 2
#
#
# ef,w. Please press enter to move a chance. You have a Two of Spades
#
# Press any key
# Top Cards on table are
#
# Two of Spades
# Two of Hearts
# Woohho Top two cards match ef,w. Wins this move
#
#
#
# No of cards with mb are 28
# No of cards with ef,w. are 24
# No of cards on table are 0
#
#
# mb Please press enter to move a chance. You have a Nine of Diamonds
#
# Press any key
# Top Cards on table are
#
# Nine of Diamonds
#
#
# No of cards with mb are 27
# No of cards with ef,w. are 24
# No of cards on table are 1
#
#
# ef,w. Please press enter to move a chance. You have a Three of Spades
# Press any key
# Top Cards on table are
#
# Three of Spades
# Nine of Diamonds
#
#
# No of cards with mb are 27
# No of cards with ef,w. are 23
# No of cards on table are 2
#
#
# mb Please press enter to move a chance. You have a Queen of Spades
#
# Press any key
# Top Cards on table are
#
# Queen of Spades
# Three of Spades
# Woohho Top two cards match mb Wins this move
#
#
#
# No of cards with mb are 29
# No of cards with ef,w. are 23
# No of cards on table are 0
#
#
# ef,w. Please press enter to move a chance. You have a Three of Diamonds
#
# Press any key
# Top Cards on table are
#
# Three of Diamonds
#
#
# No of cards with mb are 29
# No of cards with ef,w. are 22
# No of cards on table are 1
#
#
# mb Please press enter to move a chance. You have a King of Hearts
#
# Press any key
# Top Cards on table are
#
# King of Hearts
# Three of Diamonds
#
#
# No of cards with mb are 28
# No of cards with ef,w. are 22
# No of cards on table are 2
#
#
# ef,w. Please press enter to move a chance. You have a Ace of Diamonds
#
# Press any key
# Top Cards on table are
#
# Ace of Diamonds
# King of Hearts
#
#
# No of cards with mb are 28
# No of cards with ef,w. are 21
# No of cards on table are 3
#
#
# mb Please press enter to move a chance. You have a Seven of Hearts
#
# Press any key
# Top Cards on table are
#
# Seven of Hearts
# Ace of Diamonds
#
#
# No of cards with mb are 27
# No of cards with ef,w. are 21
# No of cards on table are 4
#
#
# ef,w. Please press enter to move a chance. You have a Four of Spades
#
# Press any key
# Top Cards on table are
#
# Four of Spades
# Seven of Hearts
#
#
# No of cards with mb are 27
# No of cards with ef,w. are 20
# No of cards on table are 5
#
#
# mb Please press enter to move a chance. You have a Seven of Diamonds
#
# Press any key
# Top Cards on table are
#
# Seven of Diamonds
# Four of Spades
#
#
# No of cards with mb are 26
# No of cards with ef,w. are 20
# No of cards on table are 6
#
#
# ef,w. Please press enter to move a chance. You have a Three of Hearts
#
# Press any key
# Top Cards on table are
#
# Three of Hearts
# Seven of Diamonds
#
#
# No of cards with mb are 26
# No of cards with ef,w. are 19
# No of cards on table are 7
#
#
# mb Please press enter to move a chance. You have a Five of Spades
#
# Press any key
# Top Cards on table are
#
# Five of Spades
# Three of Hearts
#
#
# No of cards with mb are 25
# No of cards with ef,w. are 19
# No of cards on table are 8
#
#
# ef,w. Please press enter to move a chance. You have a Four of Hearts
#
# Press any key
# Top Cards on table are
#
# Four of Hearts
# Five of Spades
#
#
# No of cards with mb are 25
# No of cards with ef,w. are 18
# No of cards on table are 9
#
#
# mb Please press enter to move a chance. You have a Six of Hearts
#
# Press any key
# Top Cards on table are
#
# Six of Hearts
# Four of Hearts
# Woohho Top two cards match mb Wins this move
#
#
#
# No of cards with mb are 34
# No of cards with ef,w. are 18
# No of cards on table are 0
#
#
# ef,w. Please press enter to move a chance. You have a Six of Spades
#
# Press any key
# Top Cards on table are
#
# Six of Spades
#
#
# No of cards with mb are 34
# No of cards with ef,w. are 17
# No of cards on table are 1
#
#
# mb Please press enter to move a chance. You have a Five of Hearts
#
# Press any key
# Top Cards on table are
#
# Five of Hearts
# Six of Spades
#
#
# No of cards with mb are 33
# No of cards with ef,w. are 17
# No of cards on table are 2
#
#
# ef,w. Please press enter to move a chance. You have a Nine of Hearts
#
# Press any key
# Top Cards on table are
#
# Nine of Hearts
# Five of Hearts
# Woohho Top two cards match ef,w. Wins this move
#
#
#
# No of cards with mb are 33
# No of cards with ef,w. are 19
# No of cards on table are 0
#
#
# mb Please press enter to move a chance. You have a Jack of Spades
#
# Press any key
# Top Cards on table are
#
# Jack of Spades
#
#
# No of cards with mb are 32
# No of cards with ef,w. are 19
# No of cards on table are 1
#
#
# ef,w. Please press enter to move a chance. You have a Jack of Hearts
#
# Press any key
# Top Cards on table are
#
# Jack of Hearts
# Jack of Spades
# Woohho Top two cards match ef,w. Wins this move
#
#
#
# No of cards with mb are 32
# No of cards with ef,w. are 20
# No of cards on table are 0
#
#
# mb Please press enter to move a chance. You have a Seven of Spades
#
# Press any key
# Top Cards on table are
#
# Seven of Spades
#
#
# No of cards with mb are 31
# No of cards with ef,w. are 20
# No of cards on table are 1
#
#
# ef,w. Please press enter to move a chance. You have a Ace of Hearts
#
# Press any key
# Top Cards on table are
#
# Ace of Hearts
# Seven of Spades
#
#
# No of cards with mb are 31
# No of cards with ef,w. are 19
# No of cards on table are 2
#
#
# mb Please press enter to move a chance. You have a Six of Diamonds
#
# Press any key
# Top Cards on table are
#
# Six of Diamonds
# Ace of Hearts
#
#
# No of cards with mb are 30
# No of cards with ef,w. are 19
# No of cards on table are 3
#
#
# ef,w. Please press enter to move a chance. You have a Eight of Spades
#
# Press any key
# Top Cards on table are
#
# Eight of Spades
# Six of Diamonds
#
#
# No of cards with mb are 30
# No of cards with ef,w. are 18
# No of cards on table are 4
#
#
# mb Please press enter to move a chance. You have a Ten of Diamonds
#
# Press any key
# Top Cards on table are
#
# Ten of Diamonds
# Eight of Spades
#
#
# No of cards with mb are 29
# No of cards with ef,w. are 18
# No of cards on table are 5
#
#
# ef,w. Please press enter to move a chance. You have a Ten of Hearts
#
# Press any key
# Top Cards on table are
#
# Ten of Hearts
# Ten of Diamonds
# Woohho Top two cards match ef,w. Wins this move
#
#
#
# No of cards with mb are 29
# No of cards with ef,w. are 23
# No of cards on table are 0
#
#
# mb Please press enter to move a chance. You have a Ten of Spades
#
# Press any key
# Top Cards on table are
#
# Ten of Spades
#
#
# No of cards with mb are 28
# No of cards with ef,w. are 23
# No of cards on table are 1
#
#
# ef,w. Please press enter to move a chance. You have a Nine of Clubs
#
# Press any key
# Top Cards on table are
#
# Nine of Clubs
# Ten of Spades
#
#
# No of cards with mb are 28
# No of cards with ef,w. are 22
# No of cards on table are 2
#
#
# mb Please press enter to move a chance. You have a Queen of Hearts
#
# Press any key
# Top Cards on table are
#
# Queen of Hearts
# Nine of Clubs
#
#
# No of cards with mb are 27
# No of cards with ef,w. are 22
# No of cards on table are 3
#
#
# ef,w. Please press enter to move a chance. You have a Jack of Diamonds
#
# Press any key
# Top Cards on table are
#
# Jack of Diamonds
# Queen of Hearts
#
#
# No of cards with mb are 27
# No of cards with ef,w. are 21
# No of cards on table are 4
#
#
# mb Please press enter to move a chance. You have a Queen of Diamonds
#
# Press any key
# Top Cards on table are
#
# Queen of Diamonds
# Jack of Diamonds
# Woohho Top two cards match mb Wins this move
#
#
#
# No of cards with mb are 31
# No of cards with ef,w. are 21
# No of cards on table are 0
#
#
# ef,w. Please press enter to move a chance. You have a Eight of Clubs
#
# Press any key
# Top Cards on table are
#
# Eight of Clubs
#
#
# No of cards with mb are 31
# ...
#
#
# mb Please press enter to move a chance. You have a Ace of Hearts
#
# Press any key
# Top Cards on table are
#
# Ace of Hearts
# King of Hearts
# Woohho Top two cards match mb Wins this move
#
#
#
# No of cards with mb are 8
# No of cards with ef,w. are 44
# No of cards on table are 0
#
#
# ef,w. Please press enter to move a chance. You have a Two of Diamonds
#
# Press any key
# Top Cards on table are
#
# Two of Diamonds
#
#
# No of cards with mb are 8
# No of cards with ef,w. are 43
# No of cards on table are 1
#
#
# mb Please press enter to move a chance. You have a Seven of Diamonds
#
# Press any key
# Top Cards on table are
#
# Seven of Diamonds
# Two of Diamonds
# Woohho Top two cards match mb Wins this move
#
#
#
# No of cards with mb are 9
# No of cards with ef,w. are 43
# No of cards on table are 0
#
#
# ef,w. Please press enter to move a chance. You have a Queen of Diamonds
# Press any key
# Top Cards on table are
#
# Queen of Diamonds
#
#
# No of cards with mb are 9
# No of cards with ef,w. are 42
# No of cards on table are 1
#
#
# mb Please press enter to move a chance. You have a Five of Diamonds
#
# Press any key
# Top Cards on table are
#
# Five of Diamonds
# Queen of Diamonds
# Woohho Top two cards match mb Wins this move
#
#
#
# No of cards with mb are 10
# No of cards with ef,w. are 42
# No of cards on table are 0
#
#
# ef,w. Please press enter to move a chance. You have a Two of Hearts
#
# Press any key
# Top Cards on table are
#
# Two of Hearts
#
#
# No of cards with mb are 10
# No of cards with ef,w. are 41
# No of cards on table are 1
#
#
# mb Please press enter to move a chance. You have a Six of Hearts
#
# Press any key
# Top Cards on table are
#
# Six of Hearts
# Two of Hearts
# Woohho Top two cards match mb Wins this move
#
#
#
# No of cards with mb are 11
# No of cards with ef,w. are 41
# No of cards on table are 0
#
#
# ef,w. Please press enter to move a chance. You have a Queen of Hearts
#
# Press any key
# Top Cards on table are
#
# Queen of Hearts
#
#
# No of cards with mb are 11
# No of cards with ef,w. are 40
# No of cards on table are 1
#
#
# mb Please press enter to move a chance. You have a Seven of Clubs
#
# Press any key
# Top Cards on table are
#
# Seven of Clubs
# Queen of Hearts
#
#
# No of cards with mb are 10
# No of cards with ef,w. are 40
# No of cards on table are 2
#
#
# ef,w. Please press enter to move a chance. You have a Three of Clubs
#
# Press any key
# Top Cards on table are
#
# Three of Clubs
# Seven of Clubs
# Woohho Top two cards match ef,w. Wins this move
#
#
#
# No of cards with mb are 10
# No of cards with ef,w. are 42
# No of cards on table are 0
#
#
# mb Please press enter to move a chance. You have a Eight of Clubs
#
# Press any key
# Top Cards on table are
#
# Eight of Clubs
#
#
# No of cards with mb are 9
# No of cards with ef,w. are 42
# No of cards on table are 1
#
#
# ef,w. Please press enter to move a chance. You have a Jack of Diamonds
#
# Press any key
# Top Cards on table are
#
# Jack of Diamonds
# Eight of Clubs
#
#
# No of cards with mb are 9
# No of cards with ef,w. are 41
# No of cards on table are 2
#
#
# mb Please press enter to move a chance. You have a Five of Spades
#
# Press any key
# Top Cards on table are
#
# Five of Spades
# Jack of Diamonds
#
#
# No of cards with mb are 8
# No of cards with ef,w. are 41
# No of cards on table are 3
#
#
# ef,w. Please press enter to move a chance. You have a Two of Spades
#
# Press any key
# Top Cards on table are
#
# Two of Spades
# Five of Spades
# Woohho Top two cards match ef,w. Wins this move
#
#
#
# No of cards with mb are 8
# No of cards with ef,w. are 44
# No of cards on table are 0
#
#
# mb Please press enter to move a chance. You have a Ace of Hearts
#
# Press any key
# Press any key
# Top Cards on table are
#
# Ace of Hearts
#
#
# No of cards with mb are 7
# No of cards with ef,w. are 44
# No of cards on table are 1
#
#
# ef,w. Please press enter to move a chance. You have a Ten of Spades
#
# Top Cards on table are
#
# Ten of Spades
# Ace of Hearts
#
#
# No of cards with mb are 7
# No of cards with ef,w. are 43
# No of cards on table are 2
#
#
# mb Please press enter to move a chance. You have a King of Hearts
#
# Press any key
# Top Cards on table are
#
# King of Hearts
# Ten of Spades
#
#
# No of cards with mb are 6
# No of cards with ef,w. are 43
# No of cards on table are 3
#
#
# ef,w. Please press enter to move a chance. You have a Eight of Hearts
#
# Press any key
# Top Cards on table are
#
# Eight of Hearts
# King of Hearts
# Woohho Top two cards match ef,w. Wins this move
#
#
#
# No of cards with mb are 6
# No of cards with ef,w. are 46
# No of cards on table are 0
#
#
# mb Please press enter to move a chance. You have a Seven of Diamonds
#
# Press any key
# Top Cards on table are
#
# Seven of Diamonds
#
#
# No of cards with mb are 5
# No of cards with ef,w. are 46
# No of cards on table are 1
#
#
# ef,w. Please press enter to move a chance. You have a Nine of Clubs
#
# Press any key
# Top Cards on table are
#
# Nine of Clubs
# Seven of Diamonds
#
#
# No of cards with mb are 5
# No of cards with ef,w. are 45
# No of cards on table are 2
#
#
# mb Please press enter to move a chance. You have a Two of Diamonds
#
# Press any key
# Top Cards on table are
#
# Two of Diamonds
# Nine of Clubs
#
#
# No of cards with mb are 4
# No of cards with ef,w. are 45
# No of cards on table are 3
#
#
# ef,w. Please press enter to move a chance. You have a Ten of Clubs
#
# Press any key
# Top Cards on table are
#
# Ten of Clubs
# Two of Diamonds
#
#
# No of cards with mb are 4
# No of cards with ef,w. are 44
# No of cards on table are 4
#
#
# mb Please press enter to move a chance. You have a Five of Diamonds
#
# Press any key
# Top Cards on table are
#
# Five of Diamonds
# Ten of Clubs
#
#
# No of cards with mb are 3
# No of cards with ef,w. are 44
# No of cards on table are 5
#
#
# ef,w. Please press enter to move a chance. You have a Ace of Clubs
#
# Press any key
# Top Cards on table are
#
# Ace of Clubs
# Five of Diamonds
#
#
# No of cards with mb are 3
# No of cards with ef,w. are 43
# No of cards on table are 6
#
#
# mb Please press enter to move a chance. You have a Queen of Diamonds
#
# Press any key
# Top Cards on table are
#
# Queen of Diamonds
# Ace of Clubs
#
#
# No of cards with mb are 2
# No of cards with ef,w. are 43
# No of cards on table are 7
#
#
# ef,w. Please press enter to move a chance. You have a Five of Hearts
#
# Press any key
# Top Cards on table are
#
# Five of Hearts
# Queen of Diamonds
#
#
# No of cards with mb are 2
# No of cards with ef,w. are 42
# No of cards on table are 8
#
#
# mb Please press enter to move a chance. You have a Six of Hearts
#
# Press any key
# Top Cards on table are
#
# Six of Hearts
# Five of Hearts
# Woohho Top two cards match mb Wins this move
#
#
#
# No of cards with mb are 10
# No of cards with ef,w. are 42
# No of cards on table are 0
#
#
# ef,w. Please press enter to move a chance. You have a Five of Clubs
#
# Press any key
# Top Cards on table are
#
# Five of Clubs
#
#
# No of cards with mb are 10
# No of cards with ef,w. are 41
# No of cards on table are 1
#
#
# mb Please press enter to move a chance. You have a Two of Hearts
#
# Press any key
# Top Cards on table are
#
# Two of Hearts
# Five of Clubs
#
#
# No of cards with mb are 9
# No of cards with ef,w. are 41
# No of cards on table are 2
#
#
# ef,w. Please press enter to move a chance. You have a Nine of Spades
#
# Press any key
# Top Cards on table are
#
# Nine of Spades
# Two of Hearts
#
#
# No of cards with mb are 9
# No of cards with ef,w. are 40
# No of cards on table are 3
#
#
# mb Please press enter to move a chance. You have a Six of Hearts
#
# Press any key
# Top Cards on table are
#
# Six of Hearts
# Nine of Spades
#
#
# No of cards with mb are 8
# No of cards with ef,w. are 40
# No of cards on table are 4
#
#
# ef,w. Please press enter to move a chance. You have a Four of Diamonds
#
# Press any key
# Top Cards on table are
#
# Four of Diamonds
# Six of Hearts
#
#
# No of cards with mb are 8
# No of cards with ef,w. are 39
# No of cards on table are 5
#
#
# mb Please press enter to move a chance. You have a Five of Hearts
#
# Press any key
# Top Cards on table are
#
# Five of Hearts
# Four of Diamonds
#
#
# No of cards with mb are 7
# No of cards with ef,w. are 39
# No of cards on table are 6
#
#
# ef,w. Please press enter to move a chance. You have a Six of Spades
#
# Press any key
# Top Cards on table are
#
# Six of Spades
# Five of Hearts
#
#
# No of cards with mb are 7
# No of cards with ef,w. are 38
# No of cards on table are 7
#
#
# mb Please press enter to move a chance. You have a Queen of Diamonds
#
# Press any key
# Press any key
# Top Cards on table are
#
# Queen of Diamonds
# Six of Spades
#
#
# No of cards with mb are 6
# No of cards with ef,w. are 38
# No of cards on table are 8
#
#
# ef,w. Please press enter to move a chance. You have a Queen of Clubs
#
# Top Cards on table are
#
# Queen of Clubs
# Queen of Diamonds
# Woohho Top two cards match ef,w. Wins this move
#
#
#
# No of cards with mb are 6
# No of cards with ef,w. are 46
# No of cards on table are 0
#
#
# mb Please press enter to move a chance. You have a Ace of Clubs
#
# Press any key
# Top Cards on table are
#
# Ace of Clubs
#
#
# No of cards with mb are 5
# No of cards with ef,w. are 46
# No of cards on table are 1
#
#
# ef,w. Please press enter to move a chance. You have a Two of Clubs
#
# Press any key
# Top Cards on table are
#
# Two of Clubs
# Ace of Clubs
# Woohho Top two cards match ef,w. Wins this move
#
#
#
# No of cards with mb are 5
# No of cards with ef,w. are 47
# No of cards on table are 0
#
#
# mb Please press enter to move a chance. You have a Five of Diamonds
#
# Press any key
# Top Cards on table are
#
# Five of Diamonds
#
#
# No of cards with mb are 4
# No of cards with ef,w. are 47
# No of cards on table are 1
#
#
# ef,w. Please press enter to move a chance. You have a Four of Clubs
#
# Press any key
# Top Cards on table are
#
# Four of Clubs
# Five of Diamonds
#
#
# No of cards with mb are 4
# No of cards with ef,w. are 46
# No of cards on table are 2
#
#
# mb Please press enter to move a chance. You have a Ten of Clubs
#
# Press any key
# Top Cards on table are
#
# Ten of Clubs
# Four of Clubs
# Woohho Top two cards match mb Wins this move
#
#
#
# No of cards with mb are 6
# No of cards with ef,w. are 46
# No of cards on table are 0
#
#
# ef,w. Please press enter to move a chance. You have a Jack of Spades
#
# Press any key
# Press any key
# Top Cards on table are
#
# Jack of Spades
#
#
# No of cards with mb are 6
# No of cards with ef,w. are 45
# No of cards on table are 1
#
#
# mb Please press enter to move a chance. You have a Two of Diamonds
#
# Top Cards on table are
#
# Two of Diamonds
# Jack of Spades
#
#
# No of cards with mb are 5
# No of cards with ef,w. are 45
# No of cards on table are 2
#
#
# ef,w. Please press enter to move a chance. You have a Jack of Clubs
#
# Press any key
# Top Cards on table are
#
# Jack of Clubs
# Two of Diamonds
#
#
# No of cards with mb are 5
# No of cards with ef,w. are 44
# No of cards on table are 3
#
#
# mb Please press enter to move a chance. You have a Nine of Clubs
#
# Press any key
# Top Cards on table are
#
# Nine of Clubs
# Jack of Clubs
# Woohho Top two cards match mb Wins this move
#
#
#
# No of cards with mb are 8
# No of cards with ef,w. are 44
# No of cards on table are 0
#
#
# ef,w. Please press enter to move a chance. You have a Nine of Hearts
#
# Press any key
# Top Cards on table are
#
# Nine of Hearts
#
#
# No of cards with mb are 8
# No of cards with ef,w. are 43
# No of cards on table are 1
#
#
# mb Please press enter to move a chance. You have a Seven of Diamonds
#
# Press any key
# Top Cards on table are
#
# Seven of Diamonds
# Nine of Hearts
#
#
# No of cards with mb are 7
# No of cards with ef,w. are 43
# No of cards on table are 2
#
#
# ef,w. Please press enter to move a chance. You have a Six of Clubs
#
# Press any key
# Top Cards on table are
#
# Six of Clubs
# Seven of Diamonds
#
#
# No of cards with mb are 7
# No of cards with ef,w. are 42
# No of cards on table are 3
#
#
# mb Please press enter to move a chance. You have a Ten of Clubs
#
# Press any key
# Press any key
# Top Cards on table are
#
# Ten of Clubs
# Six of Clubs
# Woohho Top two cards match mb Wins this move
#
#
#
# No of cards with mb are 10
# No of cards with ef,w. are 42
# No of cards on table are 0
#
#
# ef,w. Please press enter to move a chance. You have a Jack of Hearts
#
# Top Cards on table are
#
# Jack of Hearts
#
#
# No of cards with mb are 10
# No of cards with ef,w. are 41
# No of cards on table are 1
#
#
# mb Please press enter to move a chance. You have a Four of Clubs
#
# Press any key
# Top Cards on table are
#
# Four of Clubs
# Jack of Hearts
#
#
# No of cards with mb are 9
# No of cards with ef,w. are 41
# No of cards on table are 2
#
#
# ef,w. Please press enter to move a chance. You have a Three of Hearts
#
# Press any key
# Top Cards on table are
#
# Three of Hearts
# Four of Clubs
#
#
# No of cards with mb are 9
# No of cards with ef,w. are 40
# No of cards on table are 3
#
#
# mb Please press enter to move a chance. You have a Five of Diamonds
#
# Press any key
# Top Cards on table are
#
# Five of Diamonds
# Three of Hearts
#
#
# No of cards with mb are 8
# No of cards with ef,w. are 40
# No of cards on table are 4
#
#
# ef,w. Please press enter to move a chance. You have a Queen of Spades
#
# Press any key
# Top Cards on table are
#
# Queen of Spades
# Five of Diamonds
#
#
# No of cards with mb are 8
# No of cards with ef,w. are 39
# No of cards on table are 5
#
#
# mb Please press enter to move a chance. You have a Nine of Clubs
#
# Press any key
# Top Cards on table are
#
# Nine of Clubs
# Queen of Spades
#
#
# No of cards with mb are 7
# No of cards with ef,w. are 39
# No of cards on table are 6
#
#
# ef,w. Please press enter to move a chance. You have a Eight of Diamonds
#
# Press any key
# Top Cards on table are
#
# Eight of Diamonds
# Nine of Clubs
#
#
# No of cards with mb are 7
# No of cards with ef,w. are 38
# No of cards on table are 7
#
#
# mb Please press enter to move a chance. You have a Jack of Clubs
#
# Press any key
# Top Cards on table are
#
# Jack of Clubs
# Eight of Diamonds
#
#
# No of cards with mb are 6
# No of cards with ef,w. are 38
# No of cards on table are 8
#
#
# ef,w. Please press enter to move a chance. You have a Ten of Hearts
#
# Press any key
# Top Cards on table are
#
# Ten of Hearts
# Jack of Clubs
#
#
# No of cards with mb are 6
# No of cards with ef,w. are 37
# No of cards on table are 9
#
#
# mb Please press enter to move a chance. You have a Two of Diamonds
#
# Press any key
# Top Cards on table are
#
# Two of Diamonds
# Ten of Hearts
#
#
# No of cards with mb are 5
# No of cards with ef,w. are 37
# No of cards on table are 10
#
#
# ef,w. Please press enter to move a chance. You have a Four of Hearts
#
# Press any key
# Top Cards on table are
#
# Four of Hearts
# Two of Diamonds
#
#
# No of cards with mb are 5
# No of cards with ef,w. are 36
# No of cards on table are 11
#
#
# mb Please press enter to move a chance. You have a Jack of Spades
#
# Press any key
# Top Cards on table are
#
# Jack of Spades
# Four of Hearts
#
#
# No of cards with mb are 4
# No of cards with ef,w. are 36
# No of cards on table are 12
#
#
# ef,w. Please press enter to move a chance. You have a Nine of Diamonds
#
# Press any key
# Top Cards on table are
#
# Nine of Diamonds
# Jack of Spades
#
#
# No of cards with mb are 4
# No of cards with ef,w. are 35
# No of cards on table are 13
#
#
# mb Please press enter to move a chance. You have a Ten of Clubs
#
# Press any key
# Top Cards on table are
#
# Ten of Clubs
# Nine of Diamonds
#
#
# No of cards with mb are 3
# No of cards with ef,w. are 35
# No of cards on table are 14
#
#
# ef,w. Please press enter to move a chance. You have a Three of Spades
#
# Press any key
# Top Cards on table are
#
# Three of Spades
# Ten of Clubs
#
#
# No of cards with mb are 3
# No of cards with ef,w. are 34
# No of cards on table are 15
#
#
# mb Please press enter to move a chance. You have a Six of Clubs
#
# Press any key
# Top Cards on table are
#
# Six of Clubs
# Three of Spades
#
#
# No of cards with mb are 2
# No of cards with ef,w. are 34
# No of cards on table are 16
#
#
# ef,w. Please press enter to move a chance. You have a Eight of Spades
#
# Press any key
# Top Cards on table are
#
# Eight of Spades
# Six of Clubs
#
#
# No of cards with mb are 2
# No of cards with ef,w. are 33
# No of cards on table are 17
#
#
# mb Please press enter to move a chance. You have a Seven of Diamonds
#
# Press any key
# Top Cards on table are
#
# Seven of Diamonds
# Eight of Spades
#
#
# No of cards with mb are 1
# No of cards with ef,w. are 33
# No of cards on table are 18
#
#
# ef,w. Please press enter to move a chance. You have a Ace of Spades
#
# Press any key
# Top Cards on table are
#
# Ace of Spades
# Seven of Diamonds
#
#
# No of cards with mb are 1
# No of cards with ef,w. are 32
# No of cards on table are 19
#
#
# mb Please press enter to move a chance. You have a Nine of Hearts
#
# Press any key
# Top Cards on table are
#
# Nine of Hearts
# Ace of Spades
#
#
# Congrats ef,w. Won
